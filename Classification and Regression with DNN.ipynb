# %% [markdown]
# # Classification and Regression using Deep Learning on tabular data

# %% [markdown]
# In this notebook, we'll go through the coding companion for Regression to create your very first neural network to predict whether the house price is below or above median value. We will go through the following in this notebook:
#
# - Exploring and Processing the Data
# - Building and Training our Neural Network
# - Visualizing Loss and Accuracy
# - Adding Regularization to our Neural Network
#
# The code is ready to run using house price data. Note that the results might differ because a degree of randomness in the way we split our dataset as well as the initialization of our neural network.
#
# This notebook is based on the work of Joseph Lee Wei En, 2019 at medium.com

# %% [markdown]
# # Exploring and Processing the Data

# %% [markdown]
# We first have to read in the CSV file that we've been given. We'll use a package called pandas for that:

# %%
"""%pip install pandas"""
# Out:
# '%pip install pandas'

# %%
import pandas as pd

# %%
df = pd.read_csv('housepricedata.csv', sep = ',', ) #wherever resides your data, if .ipnb and .csv are in the same folder no need to worry!
df.head(6)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
# 5    14115            5            5          796         1         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1
# 5             1             5           0         480                 0

# %%
#print(len(df. columns))
#len(df)
df.shape
# Out:
# (1460, 11)

# %% [markdown]
# The dataset that we have now is in what is called a pandas dataframe. To convert it to an array, simply access its values:

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %% [markdown]
# Now, we choose our input features and the Target we wish to predict.

# %%
X = dataset[:,0:10]
Y = dataset[:,10]

# %% [markdown]
# Normalizing our data is very important, as we want the input features to be on the same order of magnitude to make our training easier. We'll use a min-max scaler from scikit-learn which scales our data to be between 0 and 1.

# %%
"""%pip install scikit-learn
"""
# Out:
# '%pip install scikit-learn\n'

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale  # Objective, target or output variable should not be scaled
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %% [markdown]
# Lastly, we wish to set aside some parts of our dataset for a validation set and a test set. We use the function train_test_split from scikit-learn to do that.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.1)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1314, 10) (73, 10) (73, 10) (1314,) (73,) (73,)

# %% [markdown]
# # Building and Training Our First Neural Network for "Classification"

# %%
"""pip install --upgrade pip"""
# Out:
# 'pip install --upgrade pip'

# %%
"""pip install -U tensorflow """
# Out:
# 'pip install -U tensorflow '

# %% [markdown]
# We will be using Keras to build our architecture. Let's import the code from Keras that we will need to use:

# %%
"pip install protobuf==3.20.*"
# Out:
# 'pip install protobuf==3.20.*'

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# We will be using the Sequential model, which means that we merely need to describe the layers above in sequence. Our neural network has three layers:
#
# - Hidden layer 1: 32 neurons, ReLU activation
# - Hidden layer 2: 32 neurons, ReLU activation
# - Output Layer: 1 neuron, Sigmoid activation

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])
# Out:
# c:\Users\JuanC\anaconda3\envs\TecnicasAvanzadas\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now that we've got our architecture specified, we need to find the best numbers for it. Before we start our training, we have to configure the model by
# - Telling it what algorithm you want to use to do the optimization (we'll use stochastic gradient descent)
# - Telling it what loss function to use (for binary classification, we will use binary cross entropy)
# - Telling it what other metrics you want to track apart from the loss function (we want to track accuracy as well)
#
# We do so below:

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Training on the data is pretty straightforward and requires us to write one line of code. The function is called 'fit' as we are fitting the parameters to the data. We specify:
# - what data we are training on, which is X_train and Y_train
# - the size of our mini-batch
# - how long we want to train it for (epochs)
# - what our validation data is so that the model will tell us how we are doing on the validation data at each point.
#
# This function will output a history, which we save under the variable hist. We'll use this variable a little later.

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5060 - loss: 0.6946 - val_accuracy: 0.4795 - val_loss: 0.6902
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5331 - loss: 0.6806 - val_accuracy: 0.4795 - val_loss: 0.6827
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5442 - loss: 0.6742 - val_accuracy: 0.4521 - val_loss: 0.6785
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5474 - loss: 0.6653 - val_accuracy: 0.4932 - val_loss: 0.6719
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6131 - loss: 0.6622 - val_accuracy: 0.4795 - val_loss: 0.6668
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6137 - loss: 0.6519 - val_accuracy: 0.5479 - val_loss: 0.6622
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6500 - loss: 0.6474 - val_accuracy: 0.7397 - val_loss: 0.6508
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7454 - loss: 0.6394 - val_accuracy: 0.7534 - val_loss: 0.6443
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7238 - loss: 0.6353 - val_accuracy: 0.7534 - val_loss: 0.6406
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7338 - loss: 0.6210 - val_accuracy: 0.7534 - val_loss: 0.6275
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7700 - loss: 0.6193 - val_accuracy: 0.7808 - val_loss: 0.6178
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7862 - loss: 0.6067 - val_accuracy: 0.7534 - val_loss: 0.6111
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7876 - loss: 0.5942 - val_accuracy: 0.8082 - val_loss: 0.5958
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7909 - loss: 0.5887 - val_accuracy: 0.8082 - val_loss: 0.5882
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8259 - loss: 0.5770 - val_accuracy: 0.8082 - val_loss: 0.5734
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8332 - loss: 0.5670 - val_accuracy: 0.8082 - val_loss: 0.5663
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8255 - loss: 0.5535 - val_accuracy: 0.8219 - val_loss: 0.5483
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8376 - loss: 0.5425 - val_accuracy: 0.8219 - val_loss: 0.5346
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8364 - loss: 0.5296 - val_accuracy: 0.8082 - val_loss: 0.5246
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8514 - loss: 0.5161 - val_accuracy: 0.8493 - val_loss: 0.5071
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8519 - loss: 0.5111 - val_accuracy: 0.8493 - val_loss: 0.4919
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8700 - loss: 0.4947 - val_accuracy: 0.8493 - val_loss: 0.4802
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8692 - loss: 0.4819 - val_accuracy: 0.8630 - val_loss: 0.4650
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8666 - loss: 0.4613 - val_accuracy: 0.8493 - val_loss: 0.4734
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8519 - loss: 0.4694 - val_accuracy: 0.8493 - val_loss: 0.4509
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8573 - loss: 0.4513 - val_accuracy: 0.8493 - val_loss: 0.4295
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8717 - loss: 0.4350 - val_accuracy: 0.8630 - val_loss: 0.4220
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8761 - loss: 0.4260 - val_accuracy: 0.8630 - val_loss: 0.4179
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8592 - loss: 0.4298 - val_accuracy: 0.8493 - val_loss: 0.3991
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8613 - loss: 0.4148 - val_accuracy: 0.8493 - val_loss: 0.3950
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8681 - loss: 0.4150 - val_accuracy: 0.8630 - val_loss: 0.3788
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8808 - loss: 0.3864 - val_accuracy: 0.8767 - val_loss: 0.3596
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8973 - loss: 0.2606 - val_accuracy: 0.8356 - val_loss: 0.3093
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8815 - loss: 0.2891 - val_accuracy: 0.8904 - val_loss: 0.2528
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9046 - loss: 0.2621 - val_accuracy: 0.8904 - val_loss: 0.2573
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8926 - loss: 0.2785 - val_accuracy: 0.8904 - val_loss: 0.2489
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8782 - loss: 0.2941 - val_accuracy: 0.8904 - val_loss: 0.2567
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8806 - loss: 0.2884 - val_accuracy: 0.8904 - val_loss: 0.2823
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8712 - loss: 0.3065 - val_accuracy: 0.8904 - val_loss: 0.2557
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9077 - loss: 0.2812 - val_accuracy: 0.8904 - val_loss: 0.2627
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9066 - loss: 0.2594 - val_accuracy: 0.8904 - val_loss: 0.2628
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8817 - loss: 0.2839 - val_accuracy: 0.8904 - val_loss: 0.2532
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9011 - loss: 0.2547 - val_accuracy: 0.8904 - val_loss: 0.2690
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8900 - loss: 0.2633 - val_accuracy: 0.8904 - val_loss: 0.2533
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8975 - loss: 0.2577 - val_accuracy: 0.8904 - val_loss: 0.2452
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8949 - loss: 0.2789 - val_accuracy: 0.8904 - val_loss: 0.2287
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8831 - loss: 0.2996 - val_accuracy: 0.8904 - val_loss: 0.2352
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8962 - loss: 0.2761 - val_accuracy: 0.8904 - val_loss: 0.2706
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8824 - loss: 0.2683 - val_accuracy: 0.8904 - val_loss: 0.2467
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8970 - loss: 0.2500 - val_accuracy: 0.8904 - val_loss: 0.2521
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8952 - loss: 0.2798 - val_accuracy: 0.8904 - val_loss: 0.2472
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8871 - loss: 0.2748 - val_accuracy: 0.8904 - val_loss: 0.2443
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8862 - loss: 0.2675 - val_accuracy: 0.9041 - val_loss: 0.2225
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8923 - loss: 0.2957 - val_accuracy: 0.8904 - val_loss: 0.2533
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8962 - loss: 0.2692 - val_accuracy: 0.8904 - val_loss: 0.2366
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8961 - loss: 0.2760 - val_accuracy: 0.8904 - val_loss: 0.2491
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8995 - loss: 0.2524 - val_accuracy: 0.8904 - val_loss: 0.2350
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8988 - loss: 0.2442 - val_accuracy: 0.8904 - val_loss: 0.2382
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8947 - loss: 0.2633 - val_accuracy: 0.8904 - val_loss: 0.2416
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9091 - loss: 0.2375 - val_accuracy: 0.8904 - val_loss: 0.2535
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.2510 - val_accuracy: 0.8904 - val_loss: 0.2453
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9167 - loss: 0.2331 - val_accuracy: 0.8904 - val_loss: 0.2446

# %% [markdown]
# Evaluating our model on the test set:

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8846 - loss: 0.2703
# 0.8630136847496033

# %% [markdown]
# # Visualizing Loss and Accuracy

# %% [markdown]
# Import the relevant package we need to do the visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We want to visualize the training loss and the validation loss like this:

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train_loss', 'Valid_loss'], loc='upper right')
plt.show()

# %% [markdown]
# We can also visualize the training accuracy and the validation accuracy like this:

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

# %% [markdown]
# # Adding Regularization to our Neural Network

# %% [markdown]
# We'll train a model which will overfit, which we call Model 2. This might take a few minutes.

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9227 - loss: 0.1701 - val_accuracy: 0.8904 - val_loss: 0.2001
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9356 - loss: 0.1707 - val_accuracy: 0.9041 - val_loss: 0.1752
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9316 - loss: 0.1498 - val_accuracy: 0.9041 - val_loss: 0.2404
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9338 - loss: 0.1513 - val_accuracy: 0.8767 - val_loss: 0.2316
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9372 - loss: 0.1491 - val_accuracy: 0.9178 - val_loss: 0.2101
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9338 - loss: 0.1560 - val_accuracy: 0.9041 - val_loss: 0.2060
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9353 - loss: 0.1432 - val_accuracy: 0.9041 - val_loss: 0.1694
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9447 - loss: 0.1414 - val_accuracy: 0.9041 - val_loss: 0.2285
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9389 - loss: 0.1789 - val_accuracy: 0.9178 - val_loss: 0.1567
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9355 - loss: 0.1581 - val_accuracy: 0.9041 - val_loss: 0.1918
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9428 - loss: 0.1354 - val_accuracy: 0.9178 - val_loss: 0.2334
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9336 - loss: 0.1536 - val_accuracy: 0.9041 - val_loss: 0.1832
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9428 - loss: 0.1333 - val_accuracy: 0.9178 - val_loss: 0.1922
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9544 - loss: 0.1141 - val_accuracy: 0.8904 - val_loss: 0.2025
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9504 - loss: 0.1241 - val_accuracy: 0.8904 - val_loss: 0.2427
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9594 - loss: 0.1143 - val_accuracy: 0.8904 - val_loss: 0.2746
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9316 - loss: 0.1559 - val_accuracy: 0.8356 - val_loss: 0.4007
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9239 - loss: 0.2170 - val_accuracy: 0.9178 - val_loss: 0.2157
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9157 - loss: 0.1985 - val_accuracy: 0.8904 - val_loss: 0.1920
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9299 - loss: 0.1649 - val_accuracy: 0.9041 - val_loss: 0.2333
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9340 - loss: 0.1550 - val_accuracy: 0.8904 - val_loss: 0.2293
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9414 - loss: 0.1404 - val_accuracy: 0.9041 - val_loss: 0.2595
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8821 - loss: 0.2918 - val_accuracy: 0.9178 - val_loss: 0.1870
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9062 - loss: 0.1944 - val_accuracy: 0.8904 - val_loss: 0.1707
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9356 - loss: 0.1523 - val_accuracy: 0.9041 - val_loss: 0.1918

# %% [markdown]
# Let's do the same visualization to see what overfitting looks like in terms of the loss and accuracy.

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Loss for an overfitted model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])
plt.plot(hist_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# To address the overfitting we see in Model 2, we'll incorporate L2 regularization and dropout in our third model here (Model 3).

# %%
from keras.layers import Dropout
from keras import regularizers

# %%
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %%
a = 0.01
b = -0.01
c = 0.1
print(a*a)
print(b*b)
print(c*c)
# Out:
# 0.0001
# 0.0001
# 0.010000000000000002

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.5277 - loss: 19.2946 - val_accuracy: 0.8904 - val_loss: 2.0678
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8277 - loss: 1.3467 - val_accuracy: 0.8356 - val_loss: 0.5734
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8198 - loss: 0.6606 - val_accuracy: 0.8356 - val_loss: 0.5280
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8639 - loss: 0.5446 - val_accuracy: 0.8356 - val_loss: 0.5196
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8781 - loss: 0.5208 - val_accuracy: 0.8219 - val_loss: 0.5781
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8748 - loss: 0.5000 - val_accuracy: 0.8904 - val_loss: 0.4596
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8519 - loss: 0.4867 - val_accuracy: 0.8904 - val_loss: 0.4025
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8904 - loss: 0.4612 - val_accuracy: 0.8904 - val_loss: 0.4454
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.8750 - loss: 0.4902 - val_accuracy: 0.8904 - val_loss: 0.4240
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8901 - loss: 0.4504 - val_accuracy: 0.9041 - val_loss: 0.3881
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8735 - loss: 0.4548 - val_accuracy: 0.9041 - val_loss: 0.3949
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8667 - loss: 0.4839 - val_accuracy: 0.8904 - val_loss: 0.4170
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8812 - loss: 0.4442 - val_accuracy: 0.8904 - val_loss: 0.4110
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8920 - loss: 0.4378 - val_accuracy: 0.8904 - val_loss: 0.4527
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8620 - loss: 0.4688 - val_accuracy: 0.8630 - val_loss: 0.4754
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8790 - loss: 0.4558 - val_accuracy: 0.8630 - val_loss: 0.4785
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8746 - loss: 0.4884 - val_accuracy: 0.8630 - val_loss: 0.4843
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8878 - loss: 0.4610 - val_accuracy: 0.8904 - val_loss: 0.4125
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8885 - loss: 0.4390 - val_accuracy: 0.8904 - val_loss: 0.4015
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8905 - loss: 0.4559 - val_accuracy: 0.9041 - val_loss: 0.3990
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8442 - loss: 0.5258 - val_accuracy: 0.9041 - val_loss: 0.4059
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.8847 - loss: 0.4511 - val_accuracy: 0.9041 - val_loss: 0.3926
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8746 - loss: 0.4886 - val_accuracy: 0.9041 - val_loss: 0.4076
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.8789 - loss: 0.4633 - val_accuracy: 0.9041 - val_loss: 0.3914

# %% [markdown]
# We'll now plot the loss and accuracy graphs for Model 3. You'll notice that the loss is a lot higher at the start, and that's because we've changed our loss function. To plot such that the window is zoomed in between 0 and 1.2 for the loss, we add an additional line of code (plt.ylim) when plotting

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3.history['accuracy'])
plt.plot(hist_3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# As compared to Model 2, you should see that there's less overfitting!

# %%
model_3v2 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %%
model_3v2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_3v2 = model_3v2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.5673 - loss: 19.3853 - val_accuracy: 0.7260 - val_loss: 2.1607
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8152 - loss: 1.3623 - val_accuracy: 0.9178 - val_loss: 0.5402
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8531 - loss: 0.5749 - val_accuracy: 0.8904 - val_loss: 0.4757
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8387 - loss: 0.5844 - val_accuracy: 0.8356 - val_loss: 0.5476
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8590 - loss: 0.5252 - val_accuracy: 0.8493 - val_loss: 0.4975
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8598 - loss: 0.5198 - val_accuracy: 0.8904 - val_loss: 0.4601
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8852 - loss: 0.4881 - val_accuracy: 0.8904 - val_loss: 0.4356
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.8590 - loss: 0.4978 - val_accuracy: 0.9041 - val_loss: 0.4229
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8545 - loss: 0.4911 - val_accuracy: 0.8904 - val_loss: 0.4450
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8568 - loss: 0.4981 - val_accuracy: 0.8904 - val_loss: 0.4361
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8699 - loss: 0.5100 - val_accuracy: 0.8767 - val_loss: 0.4689
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.8689 - loss: 0.5025 - val_accuracy: 0.9041 - val_loss: 0.4169
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8821 - loss: 0.4706 - val_accuracy: 0.9315 - val_loss: 0.4161
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8840 - loss: 0.4421 - val_accuracy: 0.9041 - val_loss: 0.3879
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8695 - loss: 0.4617 - val_accuracy: 0.9041 - val_loss: 0.3959
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8388 - loss: 0.5417 - val_accuracy: 0.8904 - val_loss: 0.4272
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8836 - loss: 0.4564 - val_accuracy: 0.8904 - val_loss: 0.4472
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8795 - loss: 0.4765 - val_accuracy: 0.9041 - val_loss: 0.3985
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8786 - loss: 0.4571 - val_accuracy: 0.8904 - val_loss: 0.4172
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8725 - loss: 0.4627 - val_accuracy: 0.8767 - val_loss: 0.4679
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8860 - loss: 0.4496 - val_accuracy: 0.8356 - val_loss: 0.5033
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8478 - loss: 0.5614 - val_accuracy: 0.8904 - val_loss: 0.4522
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8595 - loss: 0.5012 - val_accuracy: 0.8904 - val_loss: 0.4206
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8470 - loss: 0.5383 - val_accuracy: 0.8904 - val_loss: 0.4303

# %%
plt.plot(hist_3v2.history['loss'])
plt.plot(hist_3v2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3v2.history['accuracy'])
plt.plot(hist_3v2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# What do you think? you decide which dp is better !

# %% [markdown]
# # Regression (Finding a value)

# %% [markdown]
# Which features are available in the dataset?
#
# Which features are categorical?
#
# Which features are numerical?
#
# Which features contain blank, null or empty values?
#
# What are the data types for various features?
#
# What is the distribution of numerical feature values across the samples?
#
# Which features are more correlated to the price?

# %% [markdown]
# Dataset
# This dataset contains house sale prices for King County, which includes Seattle.
# It includes homes sold between May 2014 and May 2015.
# 21 columns. (features)
# 21597 rows.
# Feature Columns
#
# id: Unique ID for each home sold
#
# date: Date of the home sale
#
# price: Price of each home sold
#
# bedrooms: Number of bedrooms
#
# bathrooms: Number of bathrooms, where .5 accounts for a room with a toilet but no shower
#
# sqft_living: Square footage of the apartments interior living space
#
# sqft_lot: Square footage of the land space
#
# floors: Number of floors
#
# waterfront: - A dummy variable for whether the apartment was overlooking the waterfront or not
#
# view: An index from 0 to 4 of how good the view of the property was
#
# condition: - An index from 1 to 5 on the condition of the apartment,
#
# grade: An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
#
# sqft_above: The square footage of the interior housing space that is above ground level
#
# sqft_basement: The square footage of the interior housing space that is below ground level
#
# yr_built: The year the house was initially built
#
# yr_renovated: The year of the house’s last renovation
#
# zipcode: What zipcode area the house is in
#
# lat: Lattitude
#
# long: Longitude
#
# sqft_living15: The square footage of interior housing living space for the nearest 15 neighbors
#
# sqft_lot15: The square footage of the land lots of the nearest 15 neighbors

# %%
# data analysis
import pandas as pd
import numpy as np

# models
from keras import layers
from keras import preprocessing
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam   # if keras does not find it

# preprocessing
from sklearn import preprocessing

# Split
from sklearn.model_selection import train_test_split

# %%
housePrices=pd.read_excel('Tabular/kc_house_data_yr.xlsx')
print(len(housePrices))

# preview the data desde la cabeza
housePrices.head()
# Out:
# 21613
#            id      date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900         3       1.00         1180      5650
# 1  6414100192  20141209  538000         3       2.25         2570      7242
# 2  5631500400  20150225  180000         2       1.00          770     10000
# 3  2487200875  20141209  604000         4       3.00         1960      5000
# 4  1954400510  20150218  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
housePrices.tail()  # previewing the data from the backwards, this is from the tail !
# Out:
#                id      date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521  360000         3       2.50         1530
# 21609  6600060120  20150223  400000         4       2.50         2310
# 21610  1523300141  20140623  402101         2       0.75         1020
# 21611   291310100  20150116  400000         3       2.50         1600
# 21612  1523300157  20141015  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [5 rows x 21 columns]

# %%
housePrices.shape
# Out:
# (21613, 21)

# %%
len(housePrices.columns)
# Out:
# 21

# %%
housePrices.dtypes   # Investigation data types is always good !  object type are strings**
# Out:
# id                 int64
# date               int64
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  int64
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(17)
# memory usage: 3.5 MB

# %% [markdown]
# Which features contain blank, null or empty values?
#
# We can check for missing values with pandas isnull(). This indicates whether values are missing or not. Then we can sum all the values to check every column.

# %%
# Number of null values per feature
housePrices.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# What is the distribution of numerical feature values across the samples?

# %%
housePrices.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# date           21613.0  2.014390e+07  4.436582e+03  2.014050e+07
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# date           2.014072e+07  2.014102e+07  2.015022e+07  2.015053e+07
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# __Completing__
#
# Since there are no missing values we do not need to complete any values.

# %% [markdown]
# __Preparation__
#
# Id feature may be dropped from our analysis since it does not add value. Date feature may be dropped since we are going to do feature engineering and make a year and month column. Zipcode feature is a special case, we could use it, but since we do not know exactly the zones of King County we are just going to drop it. Treat strings as categories. Although Zip code is numeric, we cannot treat it as a number in the model, it may be converted to a string.

# %% [markdown]
# __Creating__
#
# We may want to create a new feature called Year based on Date to analyze the price change throughout the years. We may want to create a new feature called Month based on Date to analyze the price change throughout the months.

# %% [markdown]
# __Correlation__
#
# We want to know how well does each feature correlate with Price. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
#
# Analyze by visualizing data using the __Pearson correlation matrix__
#
# It plots a coefficient to examine the strength and direction of the linear relationship between two continuous variables.
#
# The correlation coefficient can range in value from −1 to +1. The larger the absolute value of the coefficient, the stronger the relationship between the variables. For the Pearson correlation, an absolute value of 1 indicates a perfect linear relationship. A correlation close to 0 indicates no linear relationship between the variables.
#
# The sign of the coefficient indicates the direction of the relationship. If both variables tend to increase or decrease together, the coefficient is positive, and the line that represents the correlation slopes upward. If one variable tends to increase as the other decreases, the coefficient is negative, and the line that represents the correlation slopes downward.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jhon\miniconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 393.8 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 751.6 kB/s eta 0:00:01
#    --------------------------- ------------ 204.8/294.9 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style='whitegrid', font_scale=1)

plt.figure(figsize=(13,13))
plt.title('Pearson Correlation Matrix',fontsize=25)
sns.heatmap(housePrices.corr(),linewidths=0.25,vmax=0.7,square=True,cmap='GnBu',linecolor='w',
            annot=True, annot_kws={'size':7}, cbar_kws={'shrink': .7})
# Out:
# <Axes: title={'center': 'Pearson Correlation Matrix'}>

# %% [markdown]
# Which features are more correlated to the price?
#
# This allow us to explore labels that are highly correlated to the price.
# sqft_living looks like a highly correlated label to the price, as well as grade, sqft_above, sqft_living15 and bathrooms.

# %%
price_corr = housePrices.corr()['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# date             0.003033
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# __Price feature__
#
# Most of the house prices are between 0 and 1,500,000.
#
# The average house price is $540,000.
#
# Keep in mind that it may be a good idea to drop extreme values. For instance, we could focus on house from 0 to $3,000,000 and
# drop the other ones.
#
# It seems that there is a positive linear relationship between the price and sqft_living.
#
# An increase in living space generally corresponds to an increase in house price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.histplot(housePrices['price'], ax=axes[0])
sns.scatterplot(x='price',y='sqft_living', data=housePrices, ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Price in millions (USD)', ylabel='Frequency', title='Price Distribuition')
axes[1].set(xlabel='Price', ylabel='Sqft Living', title='Price vs Sqft Living')
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

# %% [markdown]
# __Bedrooms and floors box plots__
#
# Box plot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot. Outliers may be plotted as individual points. The spacings between the different parts of the box indicate the degree of dispersion (spread).
#
# We can see outliers plotted as individual points; this probably are the more expensive houses.
# We can see that the price tends to go up when the house has more bedrooms.

# %%
sns.set(style="whitegrid", font_scale=1)

f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=housePrices['bedrooms'],y=housePrices['price'], ax=axes[0])
sns.boxplot(x=housePrices['floors'],y=housePrices['price'], ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Bedrooms', ylabel='Price', title='Bedrooms vs Price Box Plot')
axes[1].set(xlabel='Floors', ylabel='Price', title='Floors vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Floors'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Floors vs Price Box Plot')]

# %% [markdown]
# __Waterfront, view and grade box plots__
#
# Waterfront houses tends to have a better price value.
# The price of waterfront houses tends to be more disperse and the price of houses without waterfront tend to be more concentrated.
# Grade and waterfront effect price. View seem to effect less but it also has an effect on price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=housePrices['waterfront'],y=housePrices['price'], ax=axes[0])
sns.boxplot(x=housePrices['view'],y=housePrices['price'], ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Waterfront', ylabel='Price', title='Waterfront vs Price Box Plot')
axes[1].set(xlabel='View', ylabel='Price', title='View vs Price Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
sns.boxplot(x=housePrices['grade'],y=housePrices['price'], ax=axe)
sns.despine(left=True, bottom=True)
axe.set(xlabel='Grade', ylabel='Price', title='Grade vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Grade'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Grade vs Price Box Plot')]

# %%
[housePrices['view'].unique().tolist() for view in housePrices.columns]
# Out:
# [[0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1]]

# %% [markdown]
# __Working with Feature Data = Feature engineering__
#
# __Correcting by dropping features__
#
# By dropping features, we are dealing with fewer data points. Speeds up our notebook and eases the analysis. Based on our assumptions and decisions we want to drop the Id, zipcode and Date features.

# %%
housePrices = housePrices.drop('id',axis=1)
housePrices = housePrices.drop('zipcode',axis=1)
print(housePrices.columns.values)
# Out:
# ['date' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15']

# %% [markdown]
# We want to engineer the date feature to make a year and month column. The feature date is as a string. With pd.to_datetime we can convert an argument to datetime.

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  int64
#  1   price          21613 non-null  int64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(15)
# memory usage: 3.1 MB

# %%
housePrices['date'] = housePrices['date'].values.astype(str)

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(16), object(1)
# memory usage: 3.5+ MB

# %%
housePrices['date'] = pd.to_datetime(housePrices['date'])

housePrices['month'] = housePrices['date'].apply(lambda date:date.month)
housePrices['year'] = housePrices['date'].apply(lambda date:date.year)

housePrices = housePrices.drop('date',axis=1)

# Check the new columns
print(housePrices.columns.values)
# Out:
# ['id' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'zipcode' 'lat' 'long' 'sqft_living15'
#  'sqft_lot15' 'month' 'year']

# %%
print('now the dataframe looks like this:')
housePrices.head(5)
# Out:
# now the dataframe looks like this:
#            id   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900         3       1.00         1180      5650     1.0
# 1  6414100192  538000         3       2.25         2570      7242     2.0
# 2  5631500400  180000         2       1.00          770     10000     1.0
# 3  2487200875  604000         4       3.00         1960      5000     1.0
# 4  1954400510  510000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014
# 2    98028  47.7379 -122.233           2720        8062      2  2015
# 3    98136  47.5208 -122.393           1360        5000     12  2014
# 4    98074  47.6168 -122.045           1800        7503      2  2015
#
# [5 rows x 22 columns]

# %% [markdown]
# __House price trends, Price vs month, vs year__
#
# Looking the box plots we notice that there is not a big difference between 2014 and 2015.
# The number of houses sold by month tends to be similar every month.
# The line plot show that around April there is an increase in house prices.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x='year',y='price',data=housePrices, ax=axes[0])
sns.boxplot(x='month',y='price',data=housePrices, ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Year', ylabel='Price', title='Price by Year Box Plot')
axes[1].set(xlabel='Month', ylabel='Price', title='Price by Month Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
housePrices.groupby('month').mean()['price'].plot()
sns.despine(left=True, bottom=True)
axe.set(xlabel='Month', ylabel='Price', title='Price Trends')
# Out:
# [Text(0.5, 0, 'Month'), Text(0, 0.5, 'Price'), Text(0.5, 1.0, 'Price Trends')]

# %% [markdown]
# __Splitting data into training, validation and testing sets__
#
# Instead of a class, Regression problems are measured by a `mean squared error or "MSE"`

# %% [markdown]
# Again, in supervised learning, we are training our model with a given dataset of examples f(X) = y, where X are a set of variables, y is the value to predict and f is the DNN !

# %%
# Features
X = housePrices.drop('price',axis=1)

# Label
y = housePrices['price']

# Split
X_train, X_valid, y_train, y_valid = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
print(X_train.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_valid.shape)
# Out:
# (15129, 21)
# (6484, 21)
# (15129,)
# (6484,)

# %% [markdown]
# __Scaling Data__
#
# In Machine Learning, including Deep Learning, Gaussian distributions are the key, so adjusting data to gaussian is kean
# Even more, having a standard deviation of 1 and median of 0 is ideal.
#
# fit_transform(X[, y]): Fit to data, then transform it.
# transform(X): Scale features of X according to feature_range.

# %%
# scaling and train test split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()

# fit and transfrom
X_train = scaler.fit_transform(X_train)

# transform for avoiding data leakage
X_valid = scaler.transform(X_valid)

# everything has been scaled between 1 and 0
print('Max: ',X_train.max())
print('Min: ', X_train.min())
# Out:
# Max:  1.0000000000000002
# Min:  0.0

# %% [markdown]
# __Creating a model == The f, the DNN__
#
# We estimate the number of neurons (units) from our features. Ex: X_train.shape (15129, 19). The optimizer is asking how you want to perform this gradient descent. In this case we are using the Adam optimizer and the mean square error loss function.

# %%
model = Sequential()

# input layer
model.add(Dense(19,activation='relu'))

# hidden layers
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# output layer
model.add(Dense(1))  # This is the decision layer class or value depending on the need !

model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# __Training the model, the f, the DNN__
#
# Now that the model, architecture, 'stomach' is ready, we can fit the model into the data.
#
# Since the dataset is large, we are going to use batch_size. It is typical to use batches of the power of 2 (32, 64, 128, 256...). In this case we are using 128. The smaller the batch size, the longer is going to take.

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_valid,y_valid.values),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 3s 8ms/step - loss: 423622213632.0000 - val_loss: 432991076352.0000
# Epoch 2/400
# 119/119 [==============================] - 1s 5ms/step - loss: 422523699200.0000 - val_loss: 429265977344.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 5ms/step - loss: 408754323456.0000 - val_loss: 397846183936.0000
# Epoch 4/400
# 119/119 [==============================] - 1s 5ms/step - loss: 343473160192.0000 - val_loss: 290072723456.0000
# Epoch 5/400
# 119/119 [==============================] - 1s 5ms/step - loss: 207517515776.0000 - val_loss: 147861798912.0000
# Epoch 6/400
# 119/119 [==============================] - 1s 5ms/step - loss: 114888859648.0000 - val_loss: 110241521664.0000
# Epoch 7/400
# 119/119 [==============================] - 1s 5ms/step - loss: 103427399680.0000 - val_loss: 108093243392.0000
# Epoch 8/400
# 119/119 [==============================] - 1s 5ms/step - loss: 101909430272.0000 - val_loss: 106568458240.0000
# Epoch 9/400
# 119/119 [==============================] - 1s 5ms/step - loss: 100477231104.0000 - val_loss: 105019990016.0000
# Epoch 10/400
# 119/119 [==============================] - 1s 5ms/step - loss: 99015188480.0000 - val_loss: 103402741760.0000
# Epoch 11/400
# 119/119 [==============================] - 1s 5ms/step - loss: 97521344512.0000 - val_loss: 101770313728.0000
# Epoch 12/400
# 119/119 [==============================] - 1s 5ms/step - loss: 95988482048.0000 - val_loss: 100048314368.0000
# Epoch 13/400
# 119/119 [==============================] - 1s 5ms/step - loss: 94345773056.0000 - val_loss: 98251530240.0000
# Epoch 14/400
# 119/119 [==============================] - 1s 5ms/step - loss: 92697223168.0000 - val_loss: 96463151104.0000
# Epoch 15/400
# 119/119 [==============================] - 1s 5ms/step - loss: 90943012864.0000 - val_loss: 94587183104.0000
# Epoch 16/400
# 119/119 [==============================] - 1s 5ms/step - loss: 89131147264.0000 - val_loss: 92493029376.0000
# Epoch 17/400
# 119/119 [==============================] - 1s 5ms/step - loss: 87189340160.0000 - val_loss: 90349748224.0000
# Epoch 18/400
# 119/119 [==============================] - 1s 5ms/step - loss: 85176582144.0000 - val_loss: 88145485824.0000
# Epoch 19/400
# 119/119 [==============================] - 1s 5ms/step - loss: 83037143040.0000 - val_loss: 85775769600.0000
# Epoch 20/400
# 119/119 [==============================] - 1s 5ms/step - loss: 80819937280.0000 - val_loss: 83288629248.0000
# Epoch 21/400
# 119/119 [==============================] - 1s 5ms/step - loss: 78495744000.0000 - val_loss: 80671293440.0000
# Epoch 22/400
# 119/119 [==============================] - 1s 5ms/step - loss: 75995406336.0000 - val_loss: 77955809280.0000
400
# 119/119 [==============================] - 1s 5ms/step - loss: 32615704576.0000 - val_loss: 32232960000.0000
# Epoch 116/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32570099712.0000 - val_loss: 32183336960.0000
# Epoch 117/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32496510976.0000 - val_loss: 32244240384.0000
# Epoch 118/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32470771712.0000 - val_loss: 32071413760.0000
# Epoch 119/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32386865152.0000 - val_loss: 32016230400.0000
# Epoch 120/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32306882560.0000 - val_loss: 31996305408.0000
# Epoch 121/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32275804160.0000 - val_loss: 31891279872.0000
# Epoch 122/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32224737280.0000 - val_loss: 31836526592.0000
# Epoch 123/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32182695936.0000 - val_loss: 31791056896.0000
# Epoch 124/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32096843776.0000 - val_loss: 31742709760.0000
# Epoch 125/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32050116608.0000 - val_loss: 31696267264.0000
# Epoch 126/400
# 119/119 [==============================] - 1s 5ms/step - loss: 32054306816.0000 - val_loss: 31676520448.0000
# Epoch 127/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31984875520.0000 - val_loss: 31585298432.0000
# Epoch 128/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31929004032.0000 - val_loss: 31551703040.0000
# Epoch 129/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31857022976.0000 - val_loss: 31463661568.0000
# Epoch 130/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31800680448.0000 - val_loss: 31416506368.0000
# Epoch 131/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31732146176.0000 - val_loss: 31541499904.0000
# Epoch 132/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31753758720.0000 - val_loss: 31393689600.0000
# Epoch 133/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31674693632.0000 - val_loss: 31291768832.0000
# Epoch 134/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31623942144.0000 - val_loss: 31261071360.0000
# Epoch 135/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31578011648.0000 - val_loss: 31210766336.0000
# Epoch 136/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31533766656.0000 - val_loss: 31145558016.0000
# Epoch 137/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31523098624.0000 - val_loss: 31196653568.0000
# Epoch 138/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31468630016.0000 - val_loss: 31062011904.0000
# Epoch 139/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31440431104.0000 - val_loss: 31161853952.0000
# Epoch 140/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31365380096.0000 - val_loss: 31051345920.0000
# Epoch 141/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31418925056.0000 - val_loss: 30957920256.0000
# Epoch 142/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31295354880.0000 - val_loss: 30951157760.0000
# Epoch 143/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31298848768.0000 - val_loss: 30889132032.0000
# Epoch 144/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31219019776.0000 - val_loss: 30834575360.0000
# Epoch 145/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31198595072.0000 - val_loss: 30873944064.0000
# Epoch 146/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31183108096.0000 - val_loss: 30787082240.0000
# Epoch 147/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31119400960.0000 - val_loss: 30723260416.0000
# Epoch 148/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31084314624.0000 - val_loss: 30687721472.0000
# Epoch 149/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31049058304.0000 - val_loss: 30747633664.0000
# Epoch 150/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31049828352.0000 - val_loss: 30663237632.0000
# Epoch 151/400
# 119/119 [==============================] - 1s 5ms/step - loss: 31017867264.0000 - val_loss: 30583115776.0000
# Epoch 152/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30960793600.0000 - val_loss: 30602326016.0000
# Epoch 153/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30951483392.0000 - val_loss: 30508857344.0000
# Epoch 154/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30878009344.0000 - val_loss: 30491987968.0000
# Epoch 155/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30868277248.0000 - val_loss: 30474981376.0000
# Epoch 156/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30850205696.0000 - val_loss: 30438578176.0000
# Epoch 157/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30804174848.0000 - val_loss: 30381701120.0000
# Epoch 158/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30754981888.0000 - val_loss: 30354518016.0000
# Epoch 159/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30719422464.0000 - val_loss: 30339530752.0000
# Epoch 160/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30688419840.0000 - val_loss: 30434349056.0000
# Epoch 161/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30695553024.0000 - val_loss: 30366388224.0000
# Epoch 162/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30648354816.0000 - val_loss: 30218622976.0000
# Epoch 163/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30609051648.0000 - val_loss: 30204604416.0000
# Epoch 164/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30586533888.0000 - val_loss: 30159863808.0000
# Epoch 165/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30561972224.0000 - val_loss: 30122665984.0000
# Epoch 166/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30504998912.0000 - val_loss: 30106028032.0000
# Epoch 167/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30527162368.0000 - val_loss: 30106550272.0000
# Epoch 168/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30448568320.0000 - val_loss: 30071891968.0000
# Epoch 169/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30424283136.0000 - val_loss: 30025222144.0000
# Epoch 170/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30380230656.0000 - val_loss: 30003535872.0000
# Epoch 171/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30368141312.0000 - val_loss: 29989781504.0000
# Epoch 172/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30365982720.0000 - val_loss: 29997516800.0000
# Epoch 173/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30311931904.0000 - val_loss: 29944295424.0000
# Epoch 174/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30316306432.0000 - val_loss: 29941948416.0000
# Epoch 175/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30293477376.0000 - val_loss: 29867249664.0000
# Epoch 176/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30189232128.0000 - val_loss: 30188046336.0000
# Epoch 177/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30258608128.0000 - val_loss: 29875134464.0000
# Epoch 178/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30195941376.0000 - val_loss: 29825404928.0000
# Epoch 179/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30145927168.0000 - val_loss: 29800243200.0000
# Epoch 180/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30145280000.0000 - val_loss: 29731360768.0000
# Epoch 181/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30094708736.0000 - val_loss: 29856866304.0000
# Epoch 182/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30118805504.0000 - val_loss: 29695477760.0000
# Epoch 183/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30071138304.0000 - val_loss: 29654564864.0000
# Epoch 184/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30053455872.0000 - val_loss: 29634220032.0000
# Epoch 185/400
# 119/119 [==============================] - 1s 5ms/step - loss: 30040696832.0000 - val_loss: 29632499712.0000
# Epoch 186/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29987801088.0000 - val_loss: 29628407808.0000
# Epoch 187/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29974190080.0000 - val_loss: 29569382400.0000
# Epoch 188/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29949874176.0000 - val_loss: 29542178816.0000
# Epoch 189/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29940680704.0000 - val_loss: 29544046592.0000
# Epoch 190/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29872850944.0000 - val_loss: 29508452352.0000
# Epoch 191/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29893347328.0000 - val_loss: 29476675584.0000
# Epoch 192/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29856151552.0000 - val_loss: 29438160896.0000
# Epoch 193/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29832235008.0000 - val_loss: 29426802688.0000
# Epoch 194/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29811982336.0000 - val_loss: 29401610240.0000
# Epoch 195/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29823612928.0000 - val_loss: 29392502784.0000
# Epoch 196/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29745836032.0000 - val_loss: 29437798400.0000
# Epoch 197/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29740500992.0000 - val_loss: 29417289728.0000
# Epoch 198/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29725800448.0000 - val_loss: 29328263168.0000
# Epoch 199/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29690249216.0000 - val_loss: 29329627136.0000
# Epoch 200/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29649096704.0000 - val_loss: 29303009280.0000
# Epoch 201/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29697337344.0000 - val_loss: 29346271232.0000
# Epoch 202/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29640478720.0000 - val_loss: 29292283904.0000
# Epoch 203/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29597683712.0000 - val_loss: 29222975488.0000
# Epoch 204/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29590755328.0000 - val_loss: 29215449088.0000
# Epoch 205/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29585459200.0000 - val_loss: 29190305792.0000
# Epoch 206/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29555419136.0000 - val_loss: 29213757440.0000
# Epoch 207/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29542014976.0000 - val_loss: 29158459392.0000
# Epoch 208/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29531183104.0000 - val_loss: 29121236992.0000
# Epoch 209/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29516589056.0000 - val_loss: 29255221248.0000
# Epoch 210/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29466970112.0000 - val_loss: 29318676480.0000
# Epoch 211/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29465417728.0000 - val_loss: 29096787968.0000
# Epoch 212/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29418573824.0000 - val_loss: 29061638144.0000
# Epoch 213/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29378365440.0000 - val_loss: 29093105664.0000
# Epoch 214/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29407076352.0000 - val_loss: 29087045632.0000
# Epoch 215/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29337020416.0000 - val_loss: 28994633728.0000
# Epoch 216/400
# 119/119 [==============================] - 1s 6ms/step - loss: 29349455872.0000 - val_loss: 29011552256.0000
# Epoch 217/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29323968512.0000 - val_loss: 29290350592.0000
# Epoch 218/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29344737280.0000 - val_loss: 28941666304.0000
# Epoch 219/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29283072000.0000 - val_loss: 28933795840.0000
# Epoch 220/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29248989184.0000 - val_loss: 28926582784.0000
# Epoch 221/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29224665088.0000 - val_loss: 28898197504.0000
# Epoch 222/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29205116928.0000 - val_loss: 28962390016.0000
# Epoch 223/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29215111168.0000 - val_loss: 28888977408.0000
# Epoch 224/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29210851328.0000 - val_loss: 28910188544.0000
# Epoch 225/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29142423552.0000 - val_loss: 28826675200.0000
# Epoch 226/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29110247424.0000 - val_loss: 28929497088.0000
# Epoch 227/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29121413120.0000 - val_loss: 28830840832.0000
# Epoch 228/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29100898304.0000 - val_loss: 28801165312.0000
# Epoch 229/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29131702272.0000 - val_loss: 28752324608.0000
# Epoch 230/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29059338240.0000 - val_loss: 28737275904.0000
# Epoch 231/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29053661184.0000 - val_loss: 28778561536.0000
# Epoch 232/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29054392320.0000 - val_loss: 28706664448.0000
# Epoch 233/400
# 119/119 [==============================] - 1s 5ms/step - loss: 29008558080.0000 - val_loss: 28688574464.0000
# Epoch 234/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28951699456.0000 - val_loss: 28670511104.0000
# Epoch 235/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28961449984.0000 - val_loss: 28733097984.0000
# Epoch 236/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28937259008.0000 - val_loss: 28697286656.0000
# Epoch 237/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28900323328.0000 - val_loss: 28661106688.0000
# Epoch 238/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28908001280.0000 - val_loss: 28617965568.0000
# Epoch 239/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28874776576.0000 - val_loss: 28603807744.0000
# Epoch 240/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28895522816.0000 - val_loss: 28653078528.0000
# Epoch 241/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28847577088.0000 - val_loss: 28686895104.0000
# Epoch 242/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28835373056.0000 - val_loss: 28556109824.0000
# Epoch 243/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28831072256.0000 - val_loss: 28800507904.0000
# Epoch 244/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28819974144.0000 - val_loss: 28554661888.0000
# Epoch 245/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28823685120.0000 - val_loss: 28510433280.0000
# Epoch 246/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28768231424.0000 - val_loss: 28491876352.0000
# Epoch 247/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28756645888.0000 - val_loss: 28503515136.0000
# Epoch 248/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28752592896.0000 - val_loss: 28527095808.0000
# Epoch 249/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28724553728.0000 - val_loss: 28440436736.0000
# Epoch 250/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28704180224.0000 - val_loss: 28408451072.0000
# Epoch 251/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28699486208.0000 - val_loss: 28406003712.0000
# Epoch 252/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28747970560.0000 - val_loss: 28399316992.0000
# Epoch 253/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28648906752.0000 - val_loss: 28405172224.0000
# Epoch 254/400
# 119/119 [==============================] - 1s 6ms/step - loss: 28626200576.0000 - val_loss: 28399337472.0000
# Epoch 255/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28637362176.0000 - val_loss: 28443021312.0000
# Epoch 256/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28607324160.0000 - val_loss: 28396410880.0000
# Epoch 257/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28570112000.0000 - val_loss: 28339888128.0000
# Epoch 258/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28571262976.0000 - val_loss: 28311109632.0000
# Epoch 259/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28548847616.0000 - val_loss: 28332593152.0000
# Epoch 260/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28537448448.0000 - val_loss: 28286447616.0000
# Epoch 261/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28496478208.0000 - val_loss: 28413642752.0000
# Epoch 262/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28503480320.0000 - val_loss: 28323725312.0000
# Epoch 263/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28484075520.0000 - val_loss: 28229416960.0000
# Epoch 264/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28462110720.0000 - val_loss: 28256700416.0000
# Epoch 265/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28437633024.0000 - val_loss: 28235112448.0000
# Epoch 266/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28457533440.0000 - val_loss: 28210247680.0000
# Epoch 267/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28453599232.0000 - val_loss: 28182343680.0000
# Epoch 268/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28403859456.0000 - val_loss: 28164124672.0000
# Epoch 269/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28400326656.0000 - val_loss: 28142385152.0000
# Epoch 270/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28372062208.0000 - val_loss: 28127696896.0000
# Epoch 271/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28360181760.0000 - val_loss: 28115695616.0000
# Epoch 272/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28290297856.0000 - val_loss: 28095322112.0000
# Epoch 273/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28326361088.0000 - val_loss: 28106807296.0000
# Epoch 274/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28315260928.0000 - val_loss: 28068550656.0000
# Epoch 275/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28286124032.0000 - val_loss: 28082642944.0000
# Epoch 276/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28264386560.0000 - val_loss: 28171851776.0000
# Epoch 277/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28253102080.0000 - val_loss: 28053583872.0000
# Epoch 278/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28263297024.0000 - val_loss: 28043747328.0000
# Epoch 279/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28231292928.0000 - val_loss: 28003915776.0000
# Epoch 280/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28187944960.0000 - val_loss: 28012816384.0000
# Epoch 281/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28154679296.0000 - val_loss: 28016013312.0000
# Epoch 282/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28164229120.0000 - val_loss: 27945357312.0000
# Epoch 283/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28112863232.0000 - val_loss: 27938564096.0000
# Epoch 284/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28115107840.0000 - val_loss: 27950712832.0000
# Epoch 285/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28107239424.0000 - val_loss: 28011665408.0000
# Epoch 286/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28069187584.0000 - val_loss: 27904563200.0000
# Epoch 287/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28056047616.0000 - val_loss: 27985739776.0000
# Epoch 288/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28051431424.0000 - val_loss: 27867523072.0000
# Epoch 289/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28039587840.0000 - val_loss: 27929872384.0000
# Epoch 290/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28022611968.0000 - val_loss: 27899795456.0000
# Epoch 291/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27999344640.0000 - val_loss: 27915196416.0000
# Epoch 292/400
# 119/119 [==============================] - 1s 5ms/step - loss: 28009175040.0000 - val_loss: 27819315200.0000
# Epoch 293/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27944323072.0000 - val_loss: 27860037632.0000
# Epoch 294/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27964925952.0000 - val_loss: 27810840576.0000
# Epoch 295/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27923578880.0000 - val_loss: 27800397824.0000
# Epoch 296/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27877822464.0000 - val_loss: 27761027072.0000
# Epoch 297/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27920463872.0000 - val_loss: 27756785664.0000
# Epoch 298/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27835002880.0000 - val_loss: 27889920000.0000
# Epoch 299/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27836168192.0000 - val_loss: 27725957120.0000
# Epoch 300/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27825303552.0000 - val_loss: 27712946176.0000
# Epoch 301/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27836825600.0000 - val_loss: 27725115392.0000
# Epoch 302/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27801569280.0000 - val_loss: 27690123264.0000
# Epoch 303/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27805720576.0000 - val_loss: 27681882112.0000
# Epoch 304/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27730743296.0000 - val_loss: 27651985408.0000
# Epoch 305/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27719292928.0000 - val_loss: 27647512576.0000
# Epoch 306/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27759450112.0000 - val_loss: 27645327360.0000
# Epoch 307/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27700254720.0000 - val_loss: 27635695616.0000
# Epoch 308/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27713030144.0000 - val_loss: 27635736576.0000
# Epoch 309/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27707428864.0000 - val_loss: 27603263488.0000
# Epoch 310/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27665876992.0000 - val_loss: 27579611136.0000
# Epoch 311/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27637538816.0000 - val_loss: 27642931200.0000
# Epoch 312/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27600967680.0000 - val_loss: 27651551232.0000
# Epoch 313/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27594815488.0000 - val_loss: 27547990016.0000
# Epoch 314/400
# 119/119 [==============================] - 1s 6ms/step - loss: 27567001600.0000 - val_loss: 27582095360.0000
# Epoch 315/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27604463616.0000 - val_loss: 27542753280.0000
# Epoch 316/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27528685568.0000 - val_loss: 27512950784.0000
# Epoch 317/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27536003072.0000 - val_loss: 27501080576.0000
# Epoch 318/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27505815552.0000 - val_loss: 27533674496.0000
# Epoch 319/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27545278464.0000 - val_loss: 27539101696.0000
# Epoch 320/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27474778112.0000 - val_loss: 27503986688.0000
# Epoch 321/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27434870784.0000 - val_loss: 27459536896.0000
# Epoch 322/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27392874496.0000 - val_loss: 27460687872.0000
# Epoch 323/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27404937216.0000 - val_loss: 27465580544.0000
# Epoch 324/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27382355968.0000 - val_loss: 27419799552.0000
# Epoch 325/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27325835264.0000 - val_loss: 27411476480.0000
# Epoch 326/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27302039552.0000 - val_loss: 27418097664.0000
# Epoch 327/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27321024512.0000 - val_loss: 27420688384.0000
# Epoch 328/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27271170048.0000 - val_loss: 27382241280.0000
# Epoch 329/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27271702528.0000 - val_loss: 27381739520.0000
# Epoch 330/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27219787776.0000 - val_loss: 27375464448.0000
# Epoch 331/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27225837568.0000 - val_loss: 27362994176.0000
# Epoch 332/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27178496000.0000 - val_loss: 27386636288.0000
# Epoch 333/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27165861888.0000 - val_loss: 27352135680.0000
# Epoch 334/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27156645888.0000 - val_loss: 27393699840.0000
# Epoch 335/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27097169920.0000 - val_loss: 27341443072.0000
# Epoch 336/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27098603520.0000 - val_loss: 27333982208.0000
# Epoch 337/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27053891584.0000 - val_loss: 27425128448.0000
# Epoch 338/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27066925056.0000 - val_loss: 27312707584.0000
# Epoch 339/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27068286976.0000 - val_loss: 27338067968.0000
# Epoch 340/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27032045568.0000 - val_loss: 27291795456.0000
# Epoch 341/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27016912896.0000 - val_loss: 27272628224.0000
# Epoch 342/400
# 119/119 [==============================] - 1s 5ms/step - loss: 27023738880.0000 - val_loss: 27273607168.0000
# Epoch 343/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26970826752.0000 - val_loss: 27412074496.0000
# Epoch 344/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26943188992.0000 - val_loss: 27247368192.0000
# Epoch 345/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26932789248.0000 - val_loss: 27277142016.0000
# Epoch 346/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26900617216.0000 - val_loss: 27225157632.0000
# Epoch 347/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26885644288.0000 - val_loss: 27236874240.0000
# Epoch 348/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26902896640.0000 - val_loss: 27196262400.0000
# Epoch 349/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26832146432.0000 - val_loss: 27278106624.0000
# Epoch 350/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26837866496.0000 - val_loss: 27185938432.0000
# Epoch 351/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26840117248.0000 - val_loss: 27161430016.0000
# Epoch 352/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26819796992.0000 - val_loss: 27285993472.0000
# Epoch 353/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26796617728.0000 - val_loss: 27169568768.0000
# Epoch 354/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26845454336.0000 - val_loss: 27121618944.0000
# Epoch 355/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26756782080.0000 - val_loss: 27101796352.0000
# Epoch 356/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26732687360.0000 - val_loss: 27096444928.0000
# Epoch 357/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26727337984.0000 - val_loss: 27077113856.0000
# Epoch 358/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26721660928.0000 - val_loss: 27132936192.0000
# Epoch 359/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26708918272.0000 - val_loss: 27084193792.0000
# Epoch 360/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26720907264.0000 - val_loss: 27037364224.0000
# Epoch 361/400
# 119/119 [==============================] - 1s 6ms/step - loss: 26684401664.0000 - val_loss: 27036735488.0000
# Epoch 362/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26673127424.0000 - val_loss: 27021707264.0000
# Epoch 363/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26648117248.0000 - val_loss: 27080470528.0000
# Epoch 364/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26613886976.0000 - val_loss: 27010514944.0000
# Epoch 365/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26623068160.0000 - val_loss: 26986283008.0000
# Epoch 366/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26585212928.0000 - val_loss: 26983792640.0000
# Epoch 367/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26581610496.0000 - val_loss: 26964310016.0000
# Epoch 368/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26550620160.0000 - val_loss: 26974769152.0000
# Epoch 369/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26569123840.0000 - val_loss: 26943891456.0000
# Epoch 370/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26524520448.0000 - val_loss: 26920507392.0000
# Epoch 371/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26516914176.0000 - val_loss: 26913406976.0000
# Epoch 372/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26489718784.0000 - val_loss: 26926381056.0000
# Epoch 373/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26475864064.0000 - val_loss: 26940231680.0000
# Epoch 374/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26510962688.0000 - val_loss: 26917949440.0000
# Epoch 375/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26478614528.0000 - val_loss: 26867212288.0000
# Epoch 376/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26432970752.0000 - val_loss: 27047729152.0000
# Epoch 377/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26459623424.0000 - val_loss: 26847299584.0000
# Epoch 378/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26434265088.0000 - val_loss: 26905769984.0000
# Epoch 379/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26410708992.0000 - val_loss: 26830788608.0000
# Epoch 380/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26368380928.0000 - val_loss: 26920744960.0000
# Epoch 381/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26365874176.0000 - val_loss: 26830915584.0000
# Epoch 382/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26345379840.0000 - val_loss: 26784233472.0000
# Epoch 383/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26328725504.0000 - val_loss: 26796429312.0000
# Epoch 384/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26335277056.0000 - val_loss: 26819354624.0000
# Epoch 385/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26324480000.0000 - val_loss: 26802552832.0000
# Epoch 386/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26296551424.0000 - val_loss: 26712104960.0000
# Epoch 387/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26263719936.0000 - val_loss: 26770055168.0000
# Epoch 388/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26247772160.0000 - val_loss: 26701352960.0000
# Epoch 389/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26261409792.0000 - val_loss: 26707335168.0000
# Epoch 390/400
# 119/119 [==============================] - 1s 5ms/step - loss: 26250893312.0000 - val_loss: 26706087936.0000
# Epoch 391/400
# ...
# Epoch 271/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30945359872.0000 - val_loss: 30446794752.0000
# Epoch 272/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30995423232.0000 - val_loss: 30338400256.0000
# Epoch 273/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30997241856.0000 - val_loss: 30313424896.0000
# Epoch 274/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30892439552.0000 - val_loss: 30402779136.0000
# Epoch 275/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30964152320.0000 - val_loss: 30299236352.0000
# Epoch 276/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30864596992.0000 - val_loss: 30326790144.0000
# Epoch 277/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30877575168.0000 - val_loss: 30300057600.0000
# Epoch 278/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30833281024.0000 - val_loss: 30296279040.0000
# Epoch 279/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30873495552.0000 - val_loss: 30305103872.0000
# Epoch 280/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30841042944.0000 - val_loss: 30258245632.0000
# Epoch 281/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30826385408.0000 - val_loss: 30233620480.0000
# Epoch 282/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30847592448.0000 - val_loss: 30256828416.0000
# Epoch 283/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30818672640.0000 - val_loss: 30218319872.0000
# Epoch 284/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30788786176.0000 - val_loss: 30204567552.0000
# Epoch 285/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30774462464.0000 - val_loss: 30252941312.0000
# Epoch 286/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30764953600.0000 - val_loss: 30191255552.0000
# Epoch 287/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30811985920.0000 - val_loss: 30244931584.0000
# Epoch 288/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30757382144.0000 - val_loss: 30167607296.0000
# Epoch 289/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30769786880.0000 - val_loss: 30272176128.0000
# Epoch 290/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30731038720.0000 - val_loss: 30145818624.0000
# Epoch 291/400
# 119/119 [==============================] - 0s 3ms/step - loss: 30729893888.0000 - val_loss: 30164258816.0000
# Epoch 292/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30700812288.0000 - val_loss: 30210136064.0000
# Epoch 293/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30714327040.0000 - val_loss: 30107953152.0000
# Epoch 294/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30730090496.0000 - val_loss: 30221101056.0000
# Epoch 295/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30680713216.0000 - val_loss: 30083289088.0000
# Epoch 296/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30641524736.0000 - val_loss: 30144149504.0000
# Epoch 297/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30649065472.0000 - val_loss: 30089691136.0000
# Epoch 298/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30662627328.0000 - val_loss: 30052614144.0000
# Epoch 299/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30699995136.0000 - val_loss: 30038024192.0000
# Epoch 300/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30647965696.0000 - val_loss: 30044497920.0000
# Epoch 301/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30642950144.0000 - val_loss: 30043985920.0000
# Epoch 302/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30616438784.0000 - val_loss: 30009288704.0000
# Epoch 303/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30616989696.0000 - val_loss: 30093602816.0000
# Epoch 304/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30598819840.0000 - val_loss: 29990875136.0000
# Epoch 305/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30612615168.0000 - val_loss: 30023114752.0000
# Epoch 306/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30563078144.0000 - val_loss: 30060961792.0000
# Epoch 307/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30526789632.0000 - val_loss: 29952931840.0000
# Epoch 308/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30584352768.0000 - val_loss: 30012297216.0000
# Epoch 309/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30547695616.0000 - val_loss: 29917274112.0000
# Epoch 310/400
# 119/119 [==============================] - 0s 3ms/step - loss: 30510872576.0000 - val_loss: 30065700864.0000
# Epoch 311/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30514980864.0000 - val_loss: 30074671104.0000
# Epoch 312/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30518251520.0000 - val_loss: 29953959936.0000
# Epoch 313/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30546722816.0000 - val_loss: 29977778176.0000
# Epoch 314/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30525345792.0000 - val_loss: 29905616896.0000
# Epoch 315/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30463367168.0000 - val_loss: 29935974400.0000
# Epoch 316/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30475585536.0000 - val_loss: 29869842432.0000
# Epoch 317/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30421227520.0000 - val_loss: 30123116544.0000
# Epoch 318/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30458075136.0000 - val_loss: 29918803968.0000
# Epoch 319/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30478323712.0000 - val_loss: 29941508096.0000
# Epoch 320/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30458529792.0000 - val_loss: 29871276032.0000
# Epoch 321/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30429440000.0000 - val_loss: 29938518016.0000
# Epoch 322/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30450204672.0000 - val_loss: 29844424704.0000
# Epoch 323/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30418579456.0000 - val_loss: 29867360256.0000
# Epoch 324/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30430763008.0000 - val_loss: 29784723456.0000
# Epoch 325/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30413957120.0000 - val_loss: 29798602752.0000
# Epoch 326/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30401931264.0000 - val_loss: 29797242880.0000
# Epoch 327/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30377410560.0000 - val_loss: 29768996864.0000
# Epoch 328/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30363201536.0000 - val_loss: 29739370496.0000
# Epoch 329/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30416967680.0000 - val_loss: 29750829056.0000
# Epoch 330/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30346506240.0000 - val_loss: 29792739328.0000
# Epoch 331/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30382006272.0000 - val_loss: 29743740928.0000
# Epoch 332/400
# 119/119 [==============================] - 0s 3ms/step - loss: 30320723968.0000 - val_loss: 29785489408.0000
# Epoch 333/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30379864064.0000 - val_loss: 29704564736.0000
# Epoch 334/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30323924992.0000 - val_loss: 29748127744.0000
# Epoch 335/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30354214912.0000 - val_loss: 29706233856.0000
# Epoch 336/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30271924224.0000 - val_loss: 29668855808.0000
# Epoch 337/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30321698816.0000 - val_loss: 29715974144.0000
# Epoch 338/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30321022976.0000 - val_loss: 29732261888.0000
# Epoch 339/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30273341440.0000 - val_loss: 29655072768.0000
# Epoch 340/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30279124992.0000 - val_loss: 29668079616.0000
# Epoch 341/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30269276160.0000 - val_loss: 29640572928.0000
# Epoch 342/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30237878272.0000 - val_loss: 29655455744.0000
# Epoch 343/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30257831936.0000 - val_loss: 29686538240.0000
# Epoch 344/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30232514560.0000 - val_loss: 29646055424.0000
# Epoch 345/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30287669248.0000 - val_loss: 29615235072.0000
# Epoch 346/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30323095552.0000 - val_loss: 29811537920.0000
# Epoch 347/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30194405376.0000 - val_loss: 29702197248.0000
# Epoch 348/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30250160128.0000 - val_loss: 29622171648.0000
# Epoch 349/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30151397376.0000 - val_loss: 29914972160.0000
# Epoch 350/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30246586368.0000 - val_loss: 29598892032.0000
# Epoch 351/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30177355776.0000 - val_loss: 29610745856.0000
# Epoch 352/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30171121664.0000 - val_loss: 29689044992.0000
# Epoch 353/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30170413056.0000 - val_loss: 29651638272.0000
# Epoch 354/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30168729600.0000 - val_loss: 29550608384.0000
# Epoch 355/400
# 119/119 [==============================] - 0s 3ms/step - loss: 30140479488.0000 - val_loss: 29564432384.0000
# Epoch 356/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30136031232.0000 - val_loss: 29551245312.0000
# Epoch 357/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30214957056.0000 - val_loss: 29703327744.0000
# Epoch 358/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30195105792.0000 - val_loss: 29547145216.0000
# Epoch 359/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30230829056.0000 - val_loss: 29567967232.0000
# Epoch 360/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30116757504.0000 - val_loss: 29560897536.0000
# Epoch 361/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30155468800.0000 - val_loss: 29636952064.0000
# Epoch 362/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30173452288.0000 - val_loss: 29537849344.0000
# Epoch 363/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30089271296.0000 - val_loss: 29494339584.0000
# Epoch 364/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30067982336.0000 - val_loss: 29489178624.0000
# Epoch 365/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30069809152.0000 - val_loss: 29491714048.0000
# Epoch 366/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30061690880.0000 - val_loss: 29531727872.0000
# Epoch 367/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30059911168.0000 - val_loss: 29538441216.0000
# Epoch 368/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30081900544.0000 - val_loss: 29482446848.0000
# Epoch 369/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30033979392.0000 - val_loss: 29545873408.0000
# Epoch 370/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30081800192.0000 - val_loss: 29455306752.0000
# Epoch 371/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30048280576.0000 - val_loss: 29458362368.0000
# Epoch 372/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30059542528.0000 - val_loss: 29456476160.0000
# Epoch 373/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30036232192.0000 - val_loss: 29440487424.0000
# Epoch 374/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29979410432.0000 - val_loss: 29425930240.0000
# Epoch 375/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30011424768.0000 - val_loss: 29449963520.0000
# Epoch 376/400
# 119/119 [==============================] - 0s 3ms/step - loss: 30011183104.0000 - val_loss: 29461673984.0000
# Epoch 377/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30014683136.0000 - val_loss: 29426827264.0000
# Epoch 378/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30008098816.0000 - val_loss: 29458454528.0000
# Epoch 379/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29982631936.0000 - val_loss: 29432592384.0000
# Epoch 380/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30003941376.0000 - val_loss: 29394403328.0000
# Epoch 381/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30071902208.0000 - val_loss: 29396582400.0000
# Epoch 382/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29966325760.0000 - val_loss: 29504829440.0000
# Epoch 383/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29944793088.0000 - val_loss: 29383643136.0000
# Epoch 384/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29961994240.0000 - val_loss: 29418442752.0000
# Epoch 385/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29974630400.0000 - val_loss: 29372944384.0000
# Epoch 386/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29980694528.0000 - val_loss: 29411497984.0000
# Epoch 387/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29980864512.0000 - val_loss: 29360185344.0000
# Epoch 388/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29944688640.0000 - val_loss: 29339246592.0000
# Epoch 389/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29933541376.0000 - val_loss: 29336838144.0000
# Epoch 390/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29894709248.0000 - val_loss: 29335269376.0000
# Epoch 391/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29931223040.0000 - val_loss: 29496967168.0000
# Epoch 392/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29931001856.0000 - val_loss: 29337597952.0000
# Epoch 393/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29907451904.0000 - val_loss: 29368111104.0000
# Epoch 394/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29874731008.0000 - val_loss: 29326505984.0000
# Epoch 395/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29898225664.0000 - val_loss: 29316423680.0000
# Epoch 396/400
# 119/119 [==============================] - 0s 2ms/step - loss: 30000912384.0000 - val_loss: 29372692480.0000
# Epoch 397/400
# 119/119 [==============================] - 0s 3ms/step - loss: 29953851392.0000 - val_loss: 29429622784.0000
# Epoch 398/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29871927296.0000 - val_loss: 29347739648.0000
# Epoch 399/400
# 119/119 [==============================] - 0s 3ms/step - loss: 29850187776.0000 - val_loss: 29345456128.0000
# Epoch 400/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29921394688.0000 - val_loss: 29562105856.0000

# %% [markdown]
# __Training loss per epoch__
#
# This plot shows the training loss per epoch.
# This plot helps us to see if there is overfitting in the model. In this case there is no overfitting because both lines go down at the same time.

# %%
losses = pd.DataFrame(model.history.history)

plt.figure(figsize=(15,5))
sns.lineplot(data=losses,lw=3)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
sns.despine()

# %% [markdown]
# __Regression Evaluation Metrics__
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# n∑i=1/n|yi−y^i|
#
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# n∑i=1/n(yi−y^i)2
#
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# n∑i=1 √1/n(yi−y^i)2
#
#
# __Comparing these metrics__
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.

# %% [markdown]
# __Prediction (What we do on brand new data)__
#
# In this part we are giving the model the test set to get a list of predictions. Then we compare the correct values with the list of predictions. We use different metrics to compare the predictions, in this case we use MAE, MSE, RMSE and Variance Regression Score.
#
# Let us start by analyzing the MAE, which is 103,500. This means that our model is off on average about `$100,000`.
#
# Is that MAE good or bad?
#
# For that we must take into account our original data set and see what kind of values we have. For instance, the mean is 540,000, therefore the MEA is about 19% of the mean price. This is not a particularly good result.
#
# To better understand this error, we can use the variance regression score, where the best possible score is 1.0 and lower values are worse. This tells you how much variance is being explain by your model. In our case we have 0.80 which is a normal result.

# %%
# evaluation on test data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
# predictions on the test set
predictions = model.predict(X_valid)

print('MAE: ', mean_absolute_error(y_valid,predictions))
print('MSE: ', mean_squared_error(y_valid,predictions))
print('RMSE: ', np.sqrt(mean_squared_error(y_valid,predictions)))
print('Variance Regression Score: ', explained_variance_score(y_valid,predictions))

print('\n\nDescriptive Statistics:\n',housePrices['price'].describe())
# Out:
# 203/203 [==============================] - 1s 3ms/step
# MAE:  102092.46956330005
# MSE:  26590608120.12187
# RMSE:  163066.26910591248
# Variance Regression Score:  0.8105615316369865
#
#
# Descriptive Statistics:
#  count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# __Model predictions vs perfect fit__
#
# We can compare the model predictions with a perfect fit to see how accurate the model is.
#
# The red line represents the perfect prediction.
#
# We are being punish by the outliers, which are the expensive houses. Our model is not good predicting luxury houses.
#
# On the other hand, our model is good predicting the price of houses between 0 and $2 million. There is clearly a good fit.
#
# It may be worth it retraining our model just on price houses below $3 million.  df[df['price'] <= 3000000]

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))

# Our model predictions
plt.scatter(y_valid,predictions)

# Perfect predictions
plt.plot(y_valid,y_valid,'r')

errors = y_valid.values.reshape(6484, 1) - predictions
sns.histplot(errors, ax=axes[0])

sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Error', ylabel='', title='Error Histogram')
axes[1].set(xlabel='Test True Y', ylabel='Model Predictions', title='Model Predictions vs Perfect Fit')
# Out:
# [Text(0.5, 0, 'Test True Y'),
#  Text(0, 0.5, 'Model Predictions'),
#  Text(0.5, 1.0, 'Model Predictions vs Perfect Fit')]

# %% [markdown]
# __Predicting a new comer house__
#
# We are going to use the model to predict the price on a brand-new house. We are going to choose the first house of the data set and drop the price. single_house is going to have all the features that we need to predict the price. After that we need to reshape the variable and scale the features.
#
# The original price is 221,900 and the model prediction is ~ $285,000.

# %%
# features of new house
single_house = housePrices.drop('price',axis=1).iloc[0]
print(f'Features of new house:\n {single_house}')

# reshape the numpy array and scale the features
single_house = scaler.transform(single_house.values.reshape(-1, 21))

# run the model and get the price prediction
print('\nPrediction Price:', model.predict(single_house)[0,0])

# original price
print('\nOriginal Price:', housePrices.iloc[0]['price'])
# Out:
# Features of new house:
#  id               7.129301e+09
# bedrooms         3.000000e+00
# bathrooms        1.000000e+00
# sqft_living      1.180000e+03
# sqft_lot         5.650000e+03
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        3.000000e+00
# grade            7.000000e+00
# sqft_above       1.180000e+03
# sqft_basement    0.000000e+00
# yr_built         1.955000e+03
# yr_renovated     0.000000e+00
# zipcode          9.817800e+04
# lat              4.751120e+01
# long            -1.222570e+02
# sqft_living15    1.340000e+03
# sqft_lot15       5.650000e+03
# month            1.000000e+01
# year             2.014000e+03
# Name: 0, dtype: float64
# 1/1 [==============================] - 0s 73ms/step
#
# Prediction Price: 272664.5
#
# Original Price: 221900.0
# C:\Users\JHON\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Go ahead and create a model for houses with a less skewed distribution

# %%
housePrices2 = housePrices[housePrices['price'] <= 3000000]
housePrices2.head(10)
# Out:
#            id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520   221900         3       1.00         1180      5650     1.0
# 1  6414100192   538000         3       2.25         2570      7242     2.0
# 2  5631500400   180000         2       1.00          770     10000     1.0
# 3  2487200875   604000         4       3.00         1960      5000     1.0
# 4  1954400510   510000         3       2.00         1680      8080     1.0
# 5  7237550310  1225000         4       4.50         5420    101930     1.0
# 6  1321400060   257500         3       2.25         1715      6819     2.0
# 7  2008000270   291850         3       1.50         1060      9711     1.0
# 8  2414600126   229500         3       1.00         1780      7470     1.0
# 9  3793500160   323000         3       2.50         1890      6560     2.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
# 5           0     0          3  ...           1530      2001             0
# 6           0     0          3  ...              0      1995             0
# 7           0     0          3  ...              0      1963             0
# 8           0     0          3  ...            730      1960             0
# 9           0     0          3  ...              0      2003             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014
# 2    98028  47.7379 -122.233           2720        8062      2  2015
# 3    98136  47.5208 -122.393           1360        5000     12  2014
# 4    98074  47.6168 -122.045           1800        7503      2  2015
# 5    98053  47.6561 -122.005           4760      101930      5  2014
# 6    98003  47.3097 -122.327           2238        6819      6  2014
# 7    98198  47.4095 -122.315           1650        9711      1  2015
# 8    98146  47.5123 -122.337           1780        8113      4  2015
# 9    98038  47.3684 -122.031           2390        7570      3  2015
#
# [10 rows x 22 columns]
